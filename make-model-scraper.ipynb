# %%
# importing packages
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# change path if file gets moved
makes = pd.read_excel("/Users/tabithawong/Documents/make_model_webscraper/make_model(1).xlsx")

# %%
# creating the list of all boat makes from the excel file
boat_makes_list = []
for boat_make in makes[makes['Type'] == "Boat"]['Make']:
    boat_makes_list.append(boat_make)

# %%
# creating list of URLs for all the years and boat makes by appending year and replaced make
url_list = []
for boat in boat_makes_list:
    clean_boat = boat.replace("&", "and")
    final_boat = clean_boat.replace(" ", "-")
    for year in range(2010,2023):
        # check if year exists (check for not found error on page)
        # do a sleep
        url = "https://www.jdpower.com/boats/" + str(year) + "/" + final_boat.lower()
        url_list.append(url.lower())

# %%
# change base URL and inspect to get the tags
# set up soup and use soup.find_all()
URL = "https://www.jdpower.com/boats/"
page = requests.get(URL)
# Out:
# <!DOCTYPE html>
#     <html xmlns="https://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#" lang="en">
#       <head>
#
#     <!-- Google Tag Manager -->
#     <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TPZGD4Q');</script>
#     <!-- End Google Tag Manager -->
#
#
#
#           <script>
#      var noAds = 'False' == 'True';
#           </script>
#               <script type="text/javascript" src="//s.ntv.io/serve/load.js" async></script>
#                         <script>
#                   var slots = [];
#                   var googletag = googletag || {};
#                   googletag.cmd = googletag.cmd || [];
#                   (function () {
#                       var gads = document.createElement("script");
#                       gads.async = true;
#                       gads.type = "text/javascript";
#                       var useSSL = "https:" == document.location.protocol;
#                       gads.src = (useSSL ? "https:" : "https:") + "//securepubads.g.doubleclick.net/tag/js/gpt.js";
#                       var node = document.getElementsByTagName("script")[0];
#                       node.parentNode.insertBefore(gads, node);
#                   })();
#               </script>
#
#     <script src="/scriptsNDG/jdpjs.core.top?v=av2L_qD2EyPIj3UdzC35rTtbL8qhbt3YQaeifMqXXSE1"></script>
#
#
#     <!-- AdobeDTM Vars  -->
#     <script type="text/javascript">
#     var JDPjs = JDPjs || {};
#     JDPjs.DTMData = JDPjs.DTMData || {};
#
#     JDPjs.DTMData.pageName = 'Boats';
#     JDPjs.DTMData.prop35 = 'Boats';
#     JDPjs.DTMData.prop36 = '309'; //PageRouteID
#     JDPjs.DTMData.prop9 = 'Boats';
#
#     JDPjs.DTMData.prop70 = 'Unspecified';
#     JDPjs.DTMData.prop71 = 'Unspecified';
#     JDPjs.DTMData.prop72 = 'Unspecified';
#     JDPjs.DTMData.prop73 = 'Unspecified';
#     JDPjs.DTMData.prop74 = 'Unspecified';
#
#
#
#
#
#     JDPjs.DTMData.prop33 = 'Used';
#     JDPjs.DTMData.prop59 = '/boats';
#     JDPjs.DTMData.eVar3 = '/boats';
#     JDPjs.DTMData.prop61 = '200';
#     JDPjs.DTMData.visitorid = '2c9354ce-5bed-40c1-821a-0e57c98e2ca9';
#
#
#
#
#     JDPjs.DTMData.prop67 = '754c9353-fae2-4b4c-b206-ecff13c58b1a-309';
#
# /*optimizely integration*/
# window.optimizely = window.optimizely || [];
#     window.optimizely.push("activateSiteCatalyst");
#
#     /* Dummy function - remove when all s.tl() calls have been taken out (The old SiteCatalyst way) */
#     var s = (function () {
#
#         var tl = function () {
#         };
#
#         this.tl = tl;
#         return this;
#     })();
#
#     function InsertDTMData(key, value) {
#         JDPjs.DTMData[key] = value;
#     }
#     </script>
#
#
#
#
#           <script type="text/javascript">var inHeadTS = (new Date()).getTime();</script>
#
#
#
#         <script src="//assets.adobedtm.com/3b152183e4578c050a12deb8b0e5848728b8ec72/satelliteLib-07cdc8a75646a2b75d9ae206a9c4c82442a52c03.js"></script>
#
#
#
#
#
#
#           <meta charset="utf-8" />
#           <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#           <title>Power boat, Sailboat Prices &amp; Personal Watercraft Values - J.D. Power</title>
#
#               <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover">
#
#           <meta name="description" content="Power boat, Sailboat Prices &amp; Personal Watercraft Values - J.D. Power" />
#
#                       <meta name="robots" content="index all,follow all" />
#
#           <meta name="google-site-verification" content="qs6Nqp4V0yI4VXOBvfPvBZ-HU3Vw5Pw3YffFOu8n9_E" />
#           <meta name="google" content="nositelinkssearchbox" />
#           <meta property="twitter:account_id" content="15009623" />
#           <meta name="p:domain_verify" content="ff2cd2868a9b2b77335dacaad2b72c52" />
#           <meta name="msapplication-config" content="none" />
#
#
#               <link rel="canonical" href="https://www.jdpower.com/boats" />
#
#               <meta property="og:title" content="Research New Boat Prices &amp; Used Boat Values" />
#               <meta property="og:description" content="Power boat, Sailboat Prices &amp; Personal Watercraft Values - J.D. Power" />
#               <meta property="og:url" content="" />
#               <meta property="og:site_name" content="J.D. Power" />
#               <meta itemprop="name" content="Research New Boat Prices &amp; Used Boat Values" />
#               <meta itemprop="description" content="Power boat, Sailboat Prices &amp; Personal Watercraft Values - J.D. Power" />
#
#
#
#
#     <link href="/ContentNDG/jdp.landing?v=k_VOKrqlJr4v_G13AOF9pPtIc6A7KQZIpcbel1Sna5I1" rel="stylesheet"/>
#
#
#
#
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#         <script async src="https://www.googletagmanager.com/gtag/js?id=UA-891249-13"></script>
#         <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-891249-13');
#         </script>
#         <script async src="https://www.googletagmanager.com/gtag/js?id=UA-891249-29"></script>
#         <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-891249-29');
#         </script>
#
#
#     <!-- Begin comScore Tag -->
#     <script id="comscoreTag">
#         var _comscore = _comscore || [];
#         _comscore.push({ c1: "2", c2: "8590429" });
#         (function () {
#             var s = document.createElement("script"), el = document.getElementById('comscoreTag');
#             s.async = true;
#             s.src = (document.location.protocol == "https:" ? "https://sb" : "https://sb") +
#                 ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#         })();
#     </script>
#     <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=8590429&cv=2.0&cj=1" /></noscript>
#     <!-- End comScore Tag -->
#
#
#     <script type="text/javascript" language="JavaScript">
#         IsLocationAllowed = function (domainName) {
#             var domains = ["optimizely.com", "optimizelyedit.com"];
#             for (var i = 0; i < domains.length; i += 1) {
#                 if (domainName.indexOf(domains[i]) >= 0)
#                     return true;
#             }
#             return false;
#         };
#
#         if (top.location != location && !IsLocationAllowed(document.referrer)) top.location.href = location.href;
#
#     </script>
#
#
#
#               <script type="text/javascript" src="//cdn.digitalthrottle.com/pub/dt_pu176359_st322703.js"></script>
#           <!-- JAG Ensighten Container tag -->
# <script type="text/javascript">
#     dartSiteName = 'jam.jdpa.other.dfp';
#     pubTemplate = '754c9353-fae2-4b4c-b206-ecff13c58b1a-309';
#     if (window.innerWidth < 768) {
#         dartSiteName = dartSiteName.replace('.dfp', '.mob');
#         pubTemplate = pubTemplate.replace('{Device Type}', 'm');
#     }
#     else {
#         pubTemplate = pubTemplate.replace('{Device Type}', 'd');
#     }
#     var userLang = navigator.language || navigator.userLanguage;
#     jamData = {
#         "make": "",
#         "model": "",
#         "year": "2023",
#         "fuel": "",
#         "type": "",
#         "style": "",
#         "sitename": "jdpower.com",
#         "site": dartSiteName,
#         "subprod": "",
#         "adunit": "/ld",
#         "prod": "landingpage",
#         "pubtemplate": pubTemplate,
#         "browserlanguage": userLang,
#         "clc": "",
#         "multikv": "",
#         "section": "boat",
#         "modge" : ""
#     };
#
#     var paidref = _JDPjs.AdsManager.getPaidSearchRef();
#     if (paidref) {
#         jamData["paidref"] = paidref;
#     }
# </script>
#
# <script type="text/javascript" src="//nexus.ensighten.com/hearst/jumpstartauto/Bootstrap.js"></script>
# <!-- End JAG Ensighten Container tag -->
#     <script>
#         $(document).ready(function () {
#             _JDPjs.RailArticle.init();
#         });
#     </script>
#           <script type="text/javascript" src="https://cdn.cookielaw.org/consent/719c8994-8495-4716-a44c-1aea8aafb98a-test/OtAutoBlock.js" defer=""></script>
#           <script type="text/javascript" src="https://cdn.cookielaw.org/consent/719c8994-8495-4716-a44c-1aea8aafb98a-test/otSDKStub.js" data-domain-script="719c8994-8495-4716-a44c-1aea8aafb98a-test" defer=""></script>
#
#           <script type="text/javascript" defer="">
#               function OptanonWrapper() { }
#           </script>
#       </head>
# <body>
#
#     <!-- Google Tag Manager (noscript) -->
#     <noscript>
#         <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-TPZGD4Q"
#                 height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     </noscript>
#     <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <div id="device-size" style="height: 1px; width: 1px;">
#         <div id="xs" class="visible-xs"></div>
#         <div id="sm" class="visible-sm"></div>
#         <div id="md" class="visible-md"></div>
#         <div id="lg" class="visible-lg"></div>
#     </div>
#     <div class="info" style="height: 0px;"></div>
#     <script>
#         function getDeviceSize() {
#             return $('#device-size').find('div:visible').first().attr('id');
#         }
#         deviceSize = getDeviceSize();
#     </script>
#
#
#     <script>
#        // isXcelerateEnabled = 'False' === 'True' && deviceSize !== 'xs';
#         isXcelerateEnabled = 'False' === 'True';
#         jsonAdTargeting = [{"Key":"prod","Value":"landingpage"},{"Key":"yr","Value":"2023"},{"Key":"section","Value":"boat"},{"Key":"pub","Value":"jdpa"},{"Key":"pubtemplate","Value":"754c9353-fae2-4b4c-b206-ecff13c58b1a-309"}];
#         isCarsVDPPage = 'False' === 'True';
#         isSponsConsPage = 'False' === 'True';
#         isBrandPOVPage = 'False' === 'True';
#         isAdhesionAdPage = 'True' === 'True' && deviceSize === 'xs';
#         pageRouteId = 309;
#         zone = '/ld';
#         adTargeting = [{"Key":"prod","Value":"landingpage"},{"Key":"yr","Value":"2023"},{"Key":"section","Value":"boat"},{"Key":"pub","Value":"jdpa"},{"Key":"pubtemplate","Value":"754c9353-fae2-4b4c-b206-ecff13c58b1a-309"}];
#         product = 'landingpage';
#         jagBodystyle = '';
#         year = '2023';
#         jagMakeName = '';
#         jagModelName = '';
#         isAdsRefreshEligible = 'False' === 'True';
#         newUsedYearCutOff = 2021;
#         testJumpstart = 'False' === 'True';
#         jagToken = '';
#     </script>
#
#
#     <script>
#         if (!noAds) {
#             adsMgr = _JDPjs.AdsManager;
#             if ('True' === 'True') {
#                 adsMgr.init({
#                     isLandingPage: 'True' === 'True',
#                     isMakeModelPage: 'False' === 'True',
#                     isBodyStylePage: 'False' === 'True',
#                     isSuggestiveSellingPage: 'False' === 'True',
#                     isCarsVDPPage: isCarsVDPPage,
#                     isFlipbookPage: 'False' === 'True',
#                     isSponsConsPage: isSponsConsPage,
#                     isBrandPOVPage: isBrandPOVPage,
#                     removeTopMobileAd: 'False' === 'True',
#                     deviceSize: deviceSize,
#                     hasCCPAOptOut: 'False' === 'True'
#                 },
#                 {
#                     pageRouteId: pageRouteId,
#                     dartSiteName: dartSiteName,
#                     zone: zone,
#                     adTargeting: adTargeting,
#                     // delayed ads targeting
#                     product: product,
#                     jagBodystyle: jagBodystyle,
#                     year: year,
#                     jagMakeName: jagMakeName,
#                     jagModelName: jagModelName,
#                     isAdsRefreshEligible: isAdsRefreshEligible,
#                     newUsedYearCutOff: newUsedYearCutOff,
#                     isXcelerateEnabled: isXcelerateEnabled,
#                     isAdhesionAdPage: isAdhesionAdPage,
#                     deviceSize: deviceSize,
#                     testJumpstart: testJumpstart
#                 });
#             }
#         }
#     </script>
#
#
#
#     <link href="https://fonts.googleapis.com/css?family=Roboto+Condensed:400,500,700&display=swap" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Roboto:400,700&display=swap" rel="stylesheet">
#
#
# <link href="/contentndg/jdp.header?v=xpaEDDi_rr2Pt7ZuaM0-87d9dS0jngY3-3rxwJ2NWqM1" rel="stylesheet"/>
#
#
#
#
#
#
#
# <div data-v-98331908>
#     <header class="header" data-v-98331908>
#         <div class="header-container" data-v-98331908>
#             <a href="/" class="logo" data-v-98331908>
#                 <span class="u-screenreader" data-v-98331908>J.D. Power</span>
#                 <svg viewBox="0 0 158 24" xmlns="http://www.w3.org/2000/svg" class="logo-svg" data-v-98331908>
#                     <g fill="#cf202f" fill-rule="evenodd" data-v-98331908>
#                         <path d="m4.46414582 17.0255037c0 1.6626229.89543608 2.4939343 2.85394697 2.4939343 1.95851088 0 2.65564263-.8313114 2.65564263-2.4939343v-15.78877439c0-.59993657.23101428-.86407246.79730608-.86407246h2.886657c.5969574 0 .7973061.26618346.7973061.86407246v16.58937229c0 2.7908313-1.5271479 5.4178572-7.13486744 5.4178572-5.57500958 0-7.26979614-2.6270259-7.26979614-5.4178572v-1.9963759c0-.5999365.23305871-.8313114.8300161-.8313114h2.78852697c.59695739 0 .79730611.2313749.79730611.8313114v1.195778zm16.19758008 5.1189128c0 .5978889-.2003486.8313114-.797306.8313114h-2.8212371c-.5969574 0-.8300161-.2334225-.8300161-.8313114v-2.6905006c0-.597889.2310144-.833359.8300161-.833359h2.8212371c.5969574 0 .797306.23547.797306.833359z" data-v-98331908></path>
#                         <path d="m26.1058955 22.9757279c-.5315373 0-.6971318-.296897-.6971318-.8620249v-20.87697369c0-.59993657.2003488-.86407246.7973062-.86407246h7.2350417c6.0063727 0 8.0998123 2.627026 8.0998123 5.41990479v11.76735656c0 2.7928788-2.0913953 5.4178573-8.0998123 5.4178573h-7.3352161zm3.7841374-18.88264529v15.15812439h3.5510787c2.2569896 0 3.6185432-.8292639 3.6185432-2.4918867v-10.17025584c0-1.66262285-1.3615536-2.49393428-3.6185432-2.49393428h-3.5510787z" fill-rule="nonzero" data-v-98331908></path>
#                         <path d="m47.5472965 22.1444165c0 .5978889-.1983044.8313114-.797306.8313114h-2.8212371c-.5969574 0-.8279717-.2334225-.8279717-.8313114v-2.6905006c0-.597889.2310143-.833359.8279717-.833359h2.8212371c.5969573 0 .797306.23547.797306.833359z" data-v-98331908></path>
#                         <path d="m61.5001533 14.9636057v7.1500973c0 .597889-.2003487.8620249-.7973061.8620249h-2.8887014c-.5969573 0-.797306-.2641359-.797306-.8620249v-20.87697369c0-.59993657.2003487-.86407246.797306-.86407246h6.9713175c6.008417 0 8.0323478 2.627026 8.0323478 5.41990479v3.75728193c0 2.79083123-2.0239308 5.41785723-8.0323478 5.41785723h-3.28531zm0-10.87052309v7.14804969h3.28531c2.2242796 0 3.5837887-.8313114 3.5837887-2.45912563v-2.19294221c0-1.66262285-1.3595091-2.49393428-3.5837887-2.49393428h-3.28531zm14.7358523 1.431248c0-2.79287879 2.0586851-5.41785722 8.0650578-5.41785722 6.008417 0 8.0650578 2.627026 8.0650578 5.41785722v12.30177099c0 2.7908313-2.0566408 5.4178572-8.0650578 5.4178572-6.0063727 0-8.0650578-2.6270259-8.0650578-5.4178572zm11.6508909.79650282c0-1.66262285-1.3615535-2.49393427-3.5837888-2.49393427-2.2242796 0-3.553123.83131142-3.553123 2.49393427v10.70467027c0 1.6626229 1.3288434 2.4939343 3.553123 2.4939343 2.2242797 0 3.5837888-.8313114 3.5837888-2.4939343z" fill-rule="nonzero" data-v-98331908></path>
#                         <path d="m113.940407 12.5065276c.265768 1.1282084.498827 2.989445.531537 3.290437.03271-.23547.22897-1.7957146.596957-3.257676l2.853947-11.33736789c.134929-.53236693.398653-.83131143.962901-.83131143h2.522758c.596957 0 .764596.2989445.629667.83131143l-5.278575 20.94249579c-.13084.5671755-.464073.8313114-1.02832.8313114h-2.821237c-.496783 0-.797306-.2989445-.928146-.8313114l-2.921412-11.5687428c-.200348-.73098075-.431363-2.6577395-.464073-3.02630121-.03271.33375311-.300523 2.36084254-.466117 3.02630121l-2.921411 11.5687428c-.132885.5671755-.431363.8313114-1.030365.8313114h-2.819193c-.496783 0-.797306-.2989445-.93019-.8313114l-5.2744868-20.94249579c-.1308399-.53236693.03271-.83131143.6296674-.83131143h2.9541213c.5662918 0 .8300161.2989445.9629005.83131143l2.7864826 11.33736789c.298479 1.2305866.529493 2.7908312.529493 2.7908312s.165594-1.0974949.596957-2.7908312l2.855992-11.33736789c.132884-.53236693.398653-.83131143.99561-.83131143h2.688353c.596957 0 .862726.2989445.993566.83131143zm12.016833 10.4692003c-.599001 0-.797306-.2641359-.797306-.8620249v-20.87697369c0-.59993657.198305-.86612003.797306-.86612003h11.350368c.566292 0 .832061.20066138.832061.79855039v2.09465909c0 .597889-.265769.83131142-.832061.83131142h-7.666404v5.38509619h7.104201c.596958 0 .862727.19861381.862727.79855033v1.9943284c0 .5651281-.265769.7985504-.862727.7985504h-7.106245v6.1836466h7.999637c.596957 0 .827972.2006614.827972.7985504v2.0926115c0 .597889-.231015.8292639-.827972.8292639z" data-v-98331908></path>
#                         <path d="m146.634046 14.3657166v7.7479864c0 .597889-.200349.8620249-.797307.8620249h-2.884612c-.599002 0-.797306-.2641359-.797306-.8620249v-20.87697369c0-.59993657.198304-.86407246.797306-.86407246h6.967229c6.008417 0 8.034392 2.627026 8.034392 5.41990479v3.1552978c0 1.96156736-.997655 3.82280396-3.653298 4.78720716l3.585833 8.3786364c.233059.5303193-.165594.8620249-.764596.8620249h-2.921411c-.466118 0-.596957-.3317056-.830016-.8620249l-3.2526-7.7479864h-.198304zm0-10.27263399v6.54811319h3.28531c2.224279 0 3.585833-.82926389 3.585833-2.49188674v-1.56229217c0-1.66262285-1.361554-2.49393428-3.585833-2.49393428z" fill-rule="nonzero" data-v-98331908></path>
#                     </g>
#                 </svg>
#             </a>
#             <button class="menu-icon" data-v-98331908>
#                 <span class="menu-icon-span" data-v-98331908></span>
#                 <span class="u-screenreader" data-v-98331908>Navigation</span>
#             </button>
#             <ul class="nav" role="navigation" data-v-98331908>
#                 <li class="nav-item-wrap" data-v-98331908>
#                     <button class="nav-item" data-v-98331908>
#                         <span class="nav-item-span" data-v-98331908>
#                             Awards &amp; Ratings
#                             <svg class="MuiSvgIcon-root accordion-plus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true">
#                                 <path d="M19 13h-6v6h-2v-6H5v-2h6V5h2v6h6v2z"></path>
#                             </svg>
#                             <svg class="MuiSvgIcon-root accordion-minus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true"><path d="M19 13H5v-2h14v2z"></path></svg>
#                         </span>
#                     </button>
#                     <ul class="nav-dropdown-list" role="presentation" data-v-98331908>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars/rankings" data-v-98331908>Best Rated Cars & Trucks</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars/ratings" data-v-98331908>Award Winners</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars/shopping-guides" data-v-98331908>Search Articles</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars/compare-cars" data-v-98331908>Compare Cars</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars" data-v-98331908>Research by Make</a></li>
#                     </ul>
#                 </li>
#                 <li class="nav-item-wrap" data-v-98331908>
#                     <button class="nav-item" data-v-98331908>
#                         <span class="nav-item-span" data-v-98331908>
#                             Cars for Sale
#                             <svg class="MuiSvgIcon-root accordion-plus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true">
#                                 <path d="M19 13h-6v6h-2v-6H5v-2h6V5h2v6h6v2z"></path>
#                             </svg>
#                             <svg class="MuiSvgIcon-root accordion-minus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true"><path d="M19 13H5v-2h14v2z"></path></svg>
#                         </span>
#                     </button>
#                     <ul class="nav-dropdown-list" role="presentation" data-v-98331908>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/cars-for-sale" data-v-98331908>Cars for Sale</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/sell-my-car-2" data-v-98331908>Sell My Car</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="/quotes" data-v-98331908>Free Dealer Price Quote</a></li>
#                     </ul>
#                 </li>
#                 <li class="nav-item-wrap" data-v-98331908>
#                     <button class="nav-item" data-v-98331908>
#                         <span class="nav-item-span" data-v-98331908>
#                             Pricing &amp; Values
#                             <svg class="MuiSvgIcon-root accordion-plus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true">
#                                 <path d="M19 13h-6v6h-2v-6H5v-2h6V5h2v6h6v2z"></path>
#                             </svg>
#                             <svg class="MuiSvgIcon-root accordion-minus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true"><path d="M19 13H5v-2h14v2z"></path></svg>
#                         </span>
#                     </button>
#                     <ul tabindex="-1" class="nav-pricing-values-dropdown-list" role="presentation" data-v-98331908>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpower.com/cars" data-v-98331908>Autos</a></li>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpower.com/motorcycles" data-v-98331908>Motorcycles</a></li>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpower.com/rvs" data-v-98331908>RVs</a></li>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpower.com/boats" data-v-98331908>Boats</a></li>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpower.com/manufactured-homes" data-v-98331908>Manufactured Homes</a></li>
#                         <li tabindex="-1" role="presentation"data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.jdpowervalues.com" data-v-98331908>Buy B2B Valuation Products</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="small-screen-list-separator" data-v-98331908> </div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="pricing-values-blank-space" data-v-98331908> </div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="pricing-values-blank-space" data-v-98331908> </div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="pricing-values-blank-space" data-v-98331908> </div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="pricing-values-blank-space" data-v-98331908> </div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><div tabindex="-1" class="sub-heading-second" data-v-98331908>Auto Resources</div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908>
#                             <a class="pricing-values-drop-down-link drop-down-link" href="https://www.autocheck.com/vehiclehistory/?siteID=1400" data-v-98331908 rel="nofollow sponsored" target="_blank">Vehicle History Report<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"><img src="https://cdn.jdpower.com/redesign/partners/lg-autocheck-1.png" data-v-98331908 alt="autocheck" height="22"></a>
#                         </li>
#                         <li tabindex="-1" role="presentation" data-v-98331908>
#                             <a class="pricing-values-drop-down-link padding-for-separator drop-down-link" href="https://ad.doubleclick.net/ddm/trackclk/N6595.116826JDPOWERANDASSOCIATES/B7974169.328000784;dc_trk_aid=496827184;dc_trk_cid=151232386;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;ltd=" data-v-98331908 rel="nofollow sponsored" target="_blank">Insurance Center<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"><img src="https://cdn.jdpower.com/redesign/assets/autos-migration/partner-logos/geico-logo.svg" data-v-98331908 alt="geico" height="15"></a>
#                             <IMG SRC="https://ad.doubleclick.net/ddm/trackimp/N6595.116826JDPOWERANDASSOCIATES/B7974169.328000784;dc_trk_aid=496827184;dc_trk_cid=151232386;ord=133197561558140675;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua=;gdpr=${GDPR};gdpr_consent=${GDPR_CONSENT_755};ltd=?" BORDER="0" HEIGHT="1" WIDTH="1" ALT="Advertisement">
#                         </li>
#                         <li role="presentation" data-v-98331908><div tabindex="-1" class="list-separator" data-v-98331908> </div></li>
#                         <li role="presentation" data-v-98331908><div tabindex="-1" class="sub-heading-second" data-v-98331908>Specialty Resources</div></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908>
#                             <a class="pricing-values-drop-down-link drop-down-link" href="https://boathistoryreport.com/?utm_source=JDP&utm_medium=Resources&hin=&boat=&price=&utm_campaign=affiliate&newrefid=20211131453196874" data-v-98331908 rel="nofollow sponsored" target="_blank">Boat History Report<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"><img src="https://cdn.jdpower.com/redesign/assets/autos-migration/partner-logos/boathistory-logosmall.png" data-v-98331908 alt="boathistory" height="18"></a>
#                         </li>
#                         <li role="presentation" data-v-98331908>
#                             <div class="sub-heading-second" data-v-98331908>
#                                 Specialty Insurance
#                                 <a class="image-link drop-down-link" href="https://www.progressive.com/lp/recreational/?code=9106000029" data-v-98331908 rel="nofollow sponsored" target="_blank">
#                                     <img src="https://cdn.jdpower.com/redesign/assets/autos-migration/partner-logos/progressive-logo.svg" data-v-98331908 alt="progressive" height="12">
#                                 </a>
#                             </div>
#                         </li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.progressive.com/lp/motorcycle/?code=9106010020&newrefid=20211131454593880" data-v-98331908 rel="nofollow sponsored" target="_blank">Motorcycle Insurance<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"></a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.progressive.com/lp/rv/?code=9106000051&newrefid=20227281755286978" data-v-98331908 rel="nofollow sponsored" target="_blank">RV Vehicle Insurance<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"></a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="pricing-values-drop-down-link drop-down-link" href="https://www.progressive.com/lp/boat/?code=9106000029&newrefid=20211131455474290" data-v-98331908 rel="nofollow sponsored" target="_blank">Boat Insurance<img src="https://cdn.jdpower.com/jdp-web/ui-icons/external-link-icon.svg" class="external-link-icon" data-v-98331908 alt="external-link" height="15"></a></li>
#                     </ul>
#                 </li>
#                 <li class="nav-item-wrap" data-v-98331908>
#                     <button class="nav-item" data-v-98331908>
#                         <span class="nav-item-span" data-v-98331908>
#                             Business
#                             <svg class="MuiSvgIcon-root accordion-plus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true">
#                                 <path d="M19 13h-6v6h-2v-6H5v-2h6V5h2v6h6v2z"></path>
#                             </svg>
#                             <svg class="MuiSvgIcon-root accordion-minus-icon" data-v-98331908 focusable="false" viewBox="0 0 24 24" aria-hidden="true"><path d="M19 13H5v-2h14v2z"></path></svg>
#                         </span>
#                     </button>
#                     <ul class="nav-dropdown-list" role="presentation" data-v-98331908>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://www.jdpower.com/business?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>United States</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://canada.jdpower.com/?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>Canada</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://china.jdpower.com/?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>China</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://europe.jdpower.com/?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>Europe</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://japan.jdpower.com/?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>Japan</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://mexico.jdpower.com/?utm_source=Consumer&utm_medium=Link&utm_campaign=jdp_consumer" data-v-98331908>Mexico</a></li>
#                         <li tabindex="-1" role="presentation" data-v-98331908><a class="drop-down-link" href="https://www.jdpower.com/business/careers" data-v-98331908>Careers</a></li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#     </header>
#     <div class="header-overlay" data-v-98331908>
#     </div>
#     <button class="close-nav-overlay" data-v-98331908>
#         <span class="u-screenreader" data-v-98331908>Close navigation</span>
#     </button>
# </div>
#
#
# <script src="/scriptsndg/jdp.nav.js"></script>
# <script>
#     $(document).ready(function () {
#         JDPjsx.Header.Init();
#     });
# </script>
#
#
#
#
#
#
#
#
#
#
# <div class="container hidden-xs hidden-print">
#     <div class="row">
#
#
# <div class=" ad-top col-xs-12 landing__top-ad-wrap hidden-print " style="">
#     <div class="js-ad-top  js-ad-collapse-when-empty">
#             <script>
#                 if (typeof _JDPjs !== 'undefined' && typeof _JDPjs.AdsManager !== 'undefined') {
#                     var shouldDisplayAd = ('True' === 'False' && deviceSize === 'xs')
#                         || ('True' === 'True' && deviceSize !== 'xs');
#
#                     if (shouldDisplayAd) {
#                         _JDPjs.AdsManager.displayAd('.js-ad-top');
#                     }
#                 }
#             </script>
#     </div>
# </div>
#     </div>
# </div>
#
#
#     <div class="container">
#         <div class="row">
#             <div class="tab-nav-container">
#                 <a href="/cars" class="tab-nav-not-selected track-boats-head-autos">Autos</a>
#                 <a href="/motorcycles" class="tab-nav-not-selected track-boats-head-motorcycles ">Motorcycles</a>
#                 <a href="/boats" class="tab-nav-selected track-boats-head-boats">Boats</a>
#                 <a href="/rvs" class="tab-nav-not-selected track-boats-head-rvs">RVs</a>
#             </div>
#         </div>
#     </div>
#     <div class="landing-hero landing-hero--marines landing-hero--gradient">
#         <div class="container">
#             <div class="row">
#                 <div class="col-xs-12">
#                     <div class="landing-hero__content-wrap">
#                         <div class="landing-hero__content">
#         <h1 class="landing-hero__title">Boat Prices and Values </h1>
#                 <h2 class="landing-hero__subtitle">Research new and used boat pricing, specs, photos and more for anything from power boats to personal watercraft </h2>
#
#
#
#                             <a href="/boats/manufacturers" class="btn btn-xl btn-warning btn-rarrow">Start Here</a>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#
# <div class="iab-flexad js-iab-flexad ad-mobile-top visible-xs landing__top-mobile-ad hidden-print " style="">
#         <div class="iab-flexsizer js-iab-flexsizer Model.FlexRatioCssClass" style="z-index:1;padding-top:0px"></div>
#     <div class="js-ad-mobile-top iab-adcontent js-iab-adcontent js-ad-collapse-when-empty">
#             <script>
#                 if (typeof _JDPjs !== 'undefined' && typeof _JDPjs.AdsManager !== 'undefined') {
#                     var shouldDisplayAd = ('False' === 'False' && deviceSize === 'xs')
#                         || ('False' === 'True' && deviceSize !== 'xs');
#
#                     if (shouldDisplayAd) {
#                         _JDPjs.AdsManager.displayAd('.js-ad-mobile-top');
#                     }
#                 }
#             </script>
#     </div>
# </div>
#
# <div class="js-ad-page-content container landing__content js-ad-collapse-when-empty">
#     <div class="row landing__content-top landing__sect">
#         <div class="landing__content-top-l">
#
#
#
#
#
# <div class="module-head">
#     <h3>Browse by Boat Type</h3>
#     <h4>Find prices and values for all boat types below</h4>
# </div>
# <div class="bstyles-icons bstyles-icons--marines clearfix">
#         <a href="/boats/power-boats" class="bstyles-icons__icon-wrap" title="Power Boats Prices and Values">
#             <div class="bstyles-icons__icon bstyles-icons__icon--Power-Boats"></div>
#             <div class="bstyles-icons__icon-text" title="Power Boats Prices and Values">
#                 Power Boats
#             </div>
#         </a>
#         <a href="/boats/sailboats" class="bstyles-icons__icon-wrap" title="Sailboats Prices and Values">
#             <div class="bstyles-icons__icon bstyles-icons__icon--Sailboats"></div>
#             <div class="bstyles-icons__icon-text" title="Sailboats Prices and Values">
#                 Sailboats
#             </div>
#         </a>
#         <a href="/boats/personal-watercraft" class="bstyles-icons__icon-wrap" title="Personal Watercraft Prices and Values">
#             <div class="bstyles-icons__icon bstyles-icons__icon--Personal-Watercraft"></div>
#             <div class="bstyles-icons__icon-text" title="Personal Watercraft Prices and Values">
#                 Personal Watercraft
#             </div>
#         </a>
#         <a href="/boats/outboard-motors" class="bstyles-icons__icon-wrap" title="Outboard Motors Prices and Values">
#             <div class="bstyles-icons__icon bstyles-icons__icon--Outboard-Motors"></div>
#             <div class="bstyles-icons__icon-text" title="Outboard Motors Prices and Values">
#                 Outboard Motors
#             </div>
#         </a>
#         <a href="/boats/2022/trailers" class="bstyles-icons__icon-wrap" title="Boat Trailers Prices and Values">
#             <div class="bstyles-icons__icon bstyles-icons__icon--Boat-Trailers"></div>
#             <div class="bstyles-icons__icon-text" title="Boat Trailers Prices and Values">
#                 Boat Trailers
#             </div>
#         </a>
# </div>
#
#
#
# <div class="iab-flexad js-iab-flexad ad-mobile-middle visible-xs bootstrap-negative-margin hidden-print " style="">
#         <div class="iab-flexsizer js-iab-flexsizer Model.FlexRatioCssClass" style="z-index:1;padding-top:0px"></div>
#     <div class="js-ad-mobile-middle iab-adcontent js-iab-adcontent js-ad-collapse-when-empty">
#             <script>
#                 if (typeof _JDPjs !== 'undefined' && typeof _JDPjs.AdsManager !== 'undefined') {
#                     var shouldDisplayAd = ('False' === 'False' && deviceSize === 'xs')
#                         || ('False' === 'True' && deviceSize !== 'xs');
#
#                     if (shouldDisplayAd) {
#                         _JDPjs.AdsManager.displayAd('.js-ad-mobile-middle');
#                     }
#                 }
#             </script>
#     </div>
# </div>
#
# <div class="js-ad-module row link-tile-row landing__sect">
#     <div class="col-xs-12">
#         <div class="module-head title-tint">
#             <h3>Next Steps</h3>
#             <h4>Use these tools provided by J.D. Powers' trusted partners to complete your Boat shopping experience</h4>
#         </div>
#     </div>
#     <div class="partner-module-wrapper partner-make-model">
#
#
# <form id="Rollickform" action="/Page/External" target="_blank" class="partner-module-template">
#     <input id="webId" name="webId" type="hidden" value="0" />
#     <input id="utm_source" name="utm_source" type="hidden" value="BThome" />
#     <input id="routeId" name="routeId" type="hidden" value="309" />
#     <input id="RollickCat" name="RollickCat" type="hidden" value="Boat" />
#     <input id="extLinkId" name="extLinkId" type="hidden" value="999888" />
#     <input id="utm_medium" name="utm_medium" type="hidden" value="Module" />
#     <div class="partner-module__title">
#         <div class="partner-module__title-icon">
#             <svg xmlns="http://www.w3.org/2000/svg" width="28" height="28" viewBox="0 0 28 28">
#                 <path fill="#FFF" d="M2.87126784e-16,13.5839506 L2.87126784e-16,2.58620816 C2.87126784e-16,1.15786694 1.15786694,0 2.58620816,0 L13.5839506,0 C14.2698543,3.58662035e-06 14.9276638,0.272480659 15.4126692,0.757489594 L26.8287308,12.1735512 C27.8386989,13.1835194 27.8386989,14.8210202 26.8287308,15.8309883 L15.8309883,26.8287308 C14.8210202,27.8386989 13.1835194,27.8386989 12.1735512,26.8287308 L0.757489594,15.4126692 C0.272480659,14.9276638 3.58662035e-06,14.2698543 2.87126784e-16,13.5839506 Z M6.03448571,3.44827755 C4.60614449,3.44827755 3.44827755,4.60614449 3.44827755,6.03448571 C3.44827755,7.46282692 4.60614449,8.62069386 6.03448571,8.62069386 C7.46282692,8.62069386 8.62069386,7.46282692 8.62069386,6.03448571 C8.62069386,4.60614449 7.46282692,3.44827755 6.03448571,3.44827755 Z"></path>
#             </svg>
#         </div>
#         <div class="partner-module__title-text">J.D. Power Boat  Buying Program</div>
#     </div>
#     <div class="partner-module__body">
#         <div class="partner-module__text-header">Take advantage of real dealer pricing and special offers from local Certified Dealers</div>
#         <div class="paddintB10">Select your Boat to Get Started</div>
#         <div class="partner-module__select-form partner-module__select-form-4">
#             <div class="partner-module__select-form-fields type">
#                 <div class="custom-select custom-select--redesign">
#                     <select id="rollickType" name="rollickType" aria-label="Type" title="Select a Type">
#                             <option value="Showroom" >New</option>
#                             <option value="Preowned" >Used</option>
#                     </select>
#                 </div>
#             </div>
#             <div class="partner-module__select-form-fields">
#                 <input placeholder="Zip" title="Zip Code" type="text" class="input--redesign" id="txtRollickZip" name="txtRollickZip" value="" maxlength="5" aria-label="Zip" />
#             </div>
#             <div class="partner-module__select-form-fields button">
#                 <button class="btn btn-primary btn-medium btn-rarrow btn-full btn-hp-go track-rol-bt-hp-button" type="submit" id="submitSmallFYC" onclick="_gaq.push(['_trackEvent', 'ExtLinks', 'Rollick.com', 'motorcycle-vdp', 1, true]);" style="float:right;">
#                     See Dealer Pricing
#                 </button>
#             </div>
#         </div>
#     </div>
#     <div class="partner-module__footer">
#         <a class="link-tile__link text-primary text-rarrow track-rol-bt-hp-text" href="https://gorollick.com/r/start?partner=jdp" rel="nofollow" target="_blank">
#             <b>Learn More about the J.D. Power Boat Buying Program</b>
#         </a>
#     </div>
# </form>
#
#     </div>
#     <br />
#     <div class="partner-module-wrapper js-ad-module partner-vin partner-module__with-image">
#
#
#
#
# <form id="formVIN" action="/Page/External" target="_blank" class="partner-module-template link-tile__form">
#     <div class="partner-module__text-container">
#         <div class="partner-module__title">
#             <div class="partner-module__title-icon">
#                 <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30">
#                     <path fill="#FFF" d="M29.999974,14.5037969 C30.0152764,22.510062 23.275383,29.0568712 15.0108741,29.0624962 C11.4414215,29.0649572 8.1627147,27.8595643 5.58616451,25.8450488 C4.91618525,25.3212196 4.86610465,24.348503 5.47493477,23.7586972 L6.15640595,23.0985201 C6.67711115,22.5940856 7.50840075,22.5388902 8.08529541,22.9822699 C9.98358006,24.44155 12.3859368,25.3125478 14.999987,25.3125478 C21.1514938,25.3125478 26.1290096,20.4896285 26.1290096,14.5312774 C26.1290096,8.57198883 21.150526,3.75000708 14.999987,3.75000708 C12.0475299,3.75000708 9.36597978,4.86147402 7.37491296,6.67571572 L10.4447087,9.64958852 C11.0543856,10.2402146 10.6225916,11.2500212 9.76045525,11.2500212 L0.967741097,11.2500212 C0.433245592,11.2500212 0,10.8303134 0,10.3125195 L0,1.79455417 C0,0.959357279 1.04237813,0.541055708 1.65205502,1.13162323 L4.63826211,4.02451931 C7.33118316,1.53140914 10.9809582,0 14.999987,0 C23.2747782,0 29.9846716,6.49102787 29.999974,14.5037969 Z M19.0577254,19.1200556 L19.651858,18.3800151 C20.1440753,17.7669476 20.0300633,16.8834108 19.3972211,16.4066325 L16.9354692,14.5517267 L16.9354692,8.43751592 C16.9354692,7.6608543 16.2855706,7.03126327 15.4838575,7.03126327 L14.5161164,7.03126327 C13.7144034,7.03126327 13.0645048,7.6608543 13.0645048,8.43751592 L13.0645048,16.3858317 L17.0206909,19.3667358 C17.6535331,19.843514 18.5655081,19.7331232 19.0577254,19.1200556 Z" />
#                 </svg>
#             </div>
#             <div class="partner-module__title-text">Boat History Report</div>
#         </div>
#         <div class="partner-module__body">
#             <div class="partner-module__image-and-text">
#                 <div class="partner-module__text">
#                             <div class="partner-module__text-header">A boat's history affects its value. Check the history on your next boat and avoid buying a previously damaged boat.</div>
#
#                     <div class="check-list-items">
#                         <ul class="checkmark-list">
#                             <li>Check for storm damage, accidents, loss, theft, registration history and more</li>
#                             <li>Don't get stuck with an unsafe boat needing costly repairs</li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <div class="partner-module__image-container">
#         <div>
#             <a class="track-bhr-bt-hp-reportimage" target="_blank" href="/page/external/0?extLinkId=100647&routeId=0&navUrl=https%3a%2f%2fboathistoryreport.com%2f%3futm_source%3dJDP%26utm_medium%3dhomepagelargereportimage%26boat%3d%26price%3d%26utm_campaign%3daffiliate">
#                 <img class="nav-main-logo-img" src="https://cdn.jdpower.com/redesign/partners/BoatHistory_reportstack.png" alt="Boat History Report">
#             </a>
#         </div>
#     </div>
#     <div class="partner-module__vin-form">
#         <a class="track-bhr-bt-hullid" target="_blank" href="/page/external/0?extLinkId=100647&routeId=0&navUrl=https://boathistoryreport.com/?utm_source=JDP&amp;utm_medium=hullidtext&amp;boat=&amp;price=&amp;utm_campaign=affiliate&amp;hin=">
#             <div class="partner-module__vin-form-header hull-id">HULL ID</div>
#         </a>
#         <input type="text" class="form-control" title="Hull ID" placeholder="Enter Hull ID or click Get Report" name="hin" id="txtVIN" maxlength="17">
#     </div>
#
#     <div class="partner-module__footer">
#         <div class="partner-footer__logo">
#             <a class="track-bhr-bt-hp-logo"
#                target="_blank"
#                rel="nofollow"
#                data-aa-stltext=""
#                data-extlinkid="100647"
#                data-ga-action="BHR logo"
#                data-ga-category="Boat VDP Partners - T2"
#                data-ga-label="BHR logo "
#                onclick="_JDPjs.PartnerBoxes.TrackClick(this);"
#                href="/page/external/0?extLinkId=100647&routeId=0&navUrl=https%3a%2f%2fboathistoryreport.com%2f%3futm_source%3dJDP%26utm_medium%3dhomepagelargelogo%26boat%3d%26price%3d%26utm_campaign%3daffiliate">
#                 <img src="https://cdn.jdpower.com/redesign/assets/autos-migration/partner-logos/boathistorylogo125x23.png" alt="Boat History Report" />
#             </a>
#         </div>
#         <div class="partner-module__footer-button">
#             <input type="hidden" name="webId" title="Web ID" value="0">
#             <input type="hidden" name="extLinkId" title="External Link ID" value="100648">
#             <input type="hidden" name="routeId" title="Page Route ID" value="0">
#             <input type="hidden" name="navURL" title="Nav URL" value="https%3a%2f%2fboathistoryreport.com%2f%3futm_source%3dJDP%26utm_medium%3dhomepagelargelogo%26boat%3d%26price%3d%26utm_campaign%3daffiliate">
#             <a class="btn btn-primary btn-rarrow btn-block@dtmTrackingClassGoLink track-bhr-bt-hp-button"
#                data-extlinkid="100648"
#                data-ga-action="Insurance"
#                data-aa-stltext=""
#                data-ga-category="Boat VDP Partners - T2"
#                data-ga-label="BHR VIN"
#                href=https://boathistoryreport.com/?utm_source=JDP&amp;utm_medium=homepagelargebutton&amp;boat=&amp;price=&amp;utm_campaign=affiliate&amp;hin=
#                onclick="_JDPjs.PartnerBoxes.TrackClick(this); updateURL();"
#                rel="nofollow"
#                id="autocheck_go_submit"
#                target="_blank">
#                 Get Report
#             </a>
#         </div>
#     </div>
# </form>
#
#
# <script type="text/javascript">
#     var vinDefault = 'Enter Hull ID or click Get Report';
# ...
#                             <path d="m146.634046 14.3657166v7.7479864c0 .597889-.200349.8620249-.797307.8620249h-2.884612c-.599002 0-.797306-.2641359-.797306-.8620249v-20.87697369c0-.59993657.198304-.86407246.797306-.86407246h6.967229c6.008417 0 8.034392 2.627026 8.034392 5.41990479v3.1552978c0 1.96156736-.997655 3.82280396-3.653298 4.78720716l3.585833 8.3786364c.233059.5303193-.165594.8620249-.764596.8620249h-2.921411c-.466118 0-.596957-.3317056-.830016-.8620249l-3.2526-7.7479864h-.198304zm0-10.27263399v6.54811319h3.28531c2.224279 0 3.585833-.82926389 3.585833-2.49188674v-1.56229217c0-1.66262285-1.361554-2.49393428-3.585833-2.49393428z" fill-rule="nonzero" data-v-abfd5458></path>
#                         </g>
#                     </svg>
#                 </a>
#                 <p class="insights-text" data-v-abfd5458>
#                     Real insights from real owners
#                 </p>
#                 <ul class="social" data-v-abfd5458>
#                     <li class="social-item" data-v-abfd5458>
#                         <a href="https://www.facebook.com/jdpower/" target="_blank" title="Facebook" class="social-icon social-icon--facebook" data-v-abfd5458>
#                             <span class="u-screenreader" data-v-abfd5458>facebook</span>
#                         </a>
#                     </li>
#                     <li class="social-item" data-v-abfd5458>
#                         <a href="https://twitter.com/JDPower" target="_blank" title="Twitter" class="social-icon social-icon--twitter" data-v-abfd5458>
#                             <span class="u-screenreader" data-v-abfd5458>twitter</span>
#                         </a>
#                     </li>
#                     <li class="social-item" data-v-abfd5458>
#                         <a href="https://www.youtube.com/user/jdpowercorporate" target="_blank" title="Youtube" class="social-icon social-icon--youtube" data-v-abfd5458>
#                             <span class="u-screenreader" data-v-abfd5458>youtube</span>
#                         </a>
#                     </li>
#                     <li class="social-item" data-v-abfd5458>
#                         <a href="https://www.linkedin.com/company/j-d--power-and-associates" target="_blank" title="Linkedin" class="social-icon social-icon--linkedin" data-v-abfd5458>
#                             <span class="u-screenreader" data-v-abfd5458>linkedin</span>
#                         </a>
#                     </li>
#                 </ul>
#                 <p class="copyright copyright-big" data-v-abfd5458>
#                     © 2023 J.D.Power. All rights reserved.
#                 </p>
#             </div>
#             <div class="col-right-footer" data-v-abfd5458>
#                 <div class="footer-links-col" data-v-abfd5458>
#                     <h3 class="heading footer-heading" data-v-abfd5458>
#                         Research &amp; Shopping
#                     </h3>
#                     <ul class="footer-links-list" data-v-abfd5458>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/ratings-methodology" data-v-abfd5458>Awards &amp; Ratings</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/cars/award-summaries" data-v-abfd5458>Research</a></li>
#                         <li data-v-abfd5458>
#                             <a href="https://www.jdpower.com/cars-for-sale" class="derived-attributes router-link-exact-active router-link-active" data-v-abfd5458>
#                                 Cars for Sale
#                             </a>
#                         </li>
#                         <li data-v-abfd5458>
#                             <a href="https://www.jdpower.com/cars/incentives-and-rebates" data-v-abfd5458>
#                                 Car Deals
#                             </a>
#                         </li>
#                         <li data-v-abfd5458>
#                             <a href="https://www.jdpower.com/cars/shopping-guides" data-v-abfd5458>
#                                 Car Shopping Guides
#                             </a>
#                         </li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/cars/body-styles" data-v-abfd5458>Types of Cars</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/automotive-news" data-v-abfd5458>Automotive News</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/sell-my-car-2" data-v-abfd5458>Sell My Car</a></li>
#                     </ul>
#                 </div>
#                 <div class="footer-links-col" data-v-abfd5458>
#                     <h3 class="heading footer-heading" data-v-abfd5458>
#                         Company
#                     </h3>
#                     <ul class="footer-links-list" data-v-abfd5458>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/about-us" data-v-abfd5458>About Us</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/advertise" data-v-abfd5458>Advertise</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/cars/newsletter" data-v-abfd5458>Subscribe</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/business/careers" data-v-abfd5458>Careers</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/cars" data-v-abfd5458>Used Car Values</a></li>
#                     </ul>
#                 </div>
#                 <div class="footer-links-col" data-v-abfd5458>
#                     <h3 class="heading footer-heading" data-v-abfd5458>
#                         Legal
#                     </h3>
#                     <ul class="footer-links-list" data-v-abfd5458>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/terms-of-use" data-v-abfd5458>Terms of Use</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/privacy" data-v-abfd5458>Privacy Policy</a></li>
#                             <li data-v-abfd5458><a href="https://www.jdpower.com/privacy/california#do-not-sell" data-v-abfd5458 class="js-ccpa-do-not-sell">CA Do Not Sell or Share My Information</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/ad-choices" data-v-abfd5458>Ad Choices</a></li>
#
#                     </ul>
#                 </div>
#                 <div class="footer-links-col" data-v-abfd5458>
#                     <h3 class="heading footer-heading" data-v-abfd5458>
#                         Help &amp; Media
#                     </h3>
#                     <ul class="footer-links-list" data-v-abfd5458>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/business" data-v-abfd5458>Business Products</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/contact-us" data-v-abfd5458>Contact Us</a></li>
#                         <li data-v-abfd5458><a href="https://www.jdpower.com/accessibility" data-v-abfd5458>Accessibility</a></li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#         <p class="copyright copyright-mobile" data-v-abfd5458>
#             © 2022 J.D.Power. All rights reserved.
#         </p>
#     </div>
# </footer>
#
# <script>
#     $(document).ready(function () {
#
#             JDPZipCodejs.ZipCodeRes.Init('', 'True');
#
#
#         var tallestTitleDiv = 0;
#         var tallestBodyDiv = 0;
#         var tallestFooterDiv = 0;
#
#         $('.partner-module-half').find('.partner-module-template').each(function () {
#             if ($(this).find('.partner-module__title').height() > tallestTitleDiv) {
#                 tallestTitleDiv = $(this).find('.partner-module__title').height();
#             }
#             if ($(this).find('.partner-module__body').height() > tallestBodyDiv) {
#                 tallestBodyDiv = $(this).find('.partner-module__body').height();
#             }
#             if ($(this).find('.partner-module__footer').height() > tallestFooterDiv) {
#                 tallestFooterDiv = $(this).find('.partner-module__footer').height();
#             }
#         });
#
#         $('.partner-module-half .partner-module-template .partner-module__title').height(tallestTitleDiv);
#         $('.partner-module-half .partner-module-template .partner-module__body').height(tallestBodyDiv);
#         $('.partner-module-half .partner-module-template .partner-module__footer').height(tallestFooterDiv);
#
#         $('.js-ccpa-do-not-sell').on('click', function (ev) {
#             _JDPjs.CookieHelper.setCookie('ccpa_opt_out', 'true', new Date('2038-01-19, 03:14:08 UTC'));
#         });
#
#     });
# </script>
#
#
#     <!-- Google Code for Auto traffic - EAC cross reference -->
#     <!-- Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories. For instructions on adding this tag and more information on the above requirements, read the setup guide: google.com/ads/remarketingsetup -->
#     <script type="text/javascript">
#         /* <![CDATA[ */
#         var google_conversion_id = 1057761536;
#         var google_conversion_label = "Qwd9CPT33wMQgNKw-AM";
#         var google_custom_params = window.google_tag_params;
#         var google_remarketing_only = true;
#                 /* ]]> */
#     </script>
#     <script type="text/javascript" src="//www.googleadservices.com/pagead/conversion.js">
#     </script>
#     <noscript>
#         <div style="display: inline;">
#             <img height="1" width="1" style="border-style: none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1057761536/?value=0&amp;label=Qwd9CPT33wMQgNKw-AM&amp;guid=ON&amp;script=0" />
#         </div>
#     </noscript>
#
#
#     <script src="/scriptsNDG/jdpjs.core.bottom?v=tjYfhZ7cG9Xf-bHnIbSD35Elmk2xYs0ByLi6EUZ8Tq81"></script>
#
#     <script>
#         _JDPjs.Core.init();
#     </script>
#
#
#
# <div id='dt_13482430'>
#     <script type='text/javascript'>
#         apnTagsToLoad.push('dt_13482430');
#     </script>
# </div>
# <div id="jdpndg-auto-debug" style="display: none;">
#
# </div>
#
#
#
#     <script src="/scriptsNDG/jdp.partner-boxes.js"></script>
#
#
#     <script type="text/javascript" src="https://ws.aimbase.com/Scripts/awa.js" id="AimbaseAnalytics" data-clientId="JDP"></script>
#
#
#
#
#
#
#
#
#
#         <script type="text/javascript">if (typeof _satellite !== 'undefined') { _satellite.pageBottom(); }</script>
#
#     <div class="clearfix"></div>
#
# <div id="jam-adhesion-btm" class="jam-adhesion-ad hidden-print visible-xs">
#     <div class="iab-flexad js-iab-flexad">
#         <div class="iab-flexsizer js-iab-flexsizer flex-mob-4x1"></div>
#         <div class="iab-adcontent js-iab-adcontent js-ad-adhesion">
#             <script>
#                 if (deviceSize === 'xs') {
#                     //_JDPjs.AdsManager.displayAd('.js-ad-mobile-top');
#
#
#                     $('.js-ad-adhesion').append($('<div id="adAdhesion"></div>'));
#                     googletag.cmd.push(function () { googletag.display('adAdhesion'); });
#                 }
#             </script>
#         </div>
#     </div>
# </div>
#         <script>
#                   dartSiteName = 'jam.nag.other.dfp';
#
#                   if (deviceSize === 'xs')
#                   {
#                       dartSiteName = dartSiteName.replace('.dfp', '.mob');
#                   }
#
#                   var jSite = dartSiteName;  var jAdUnit = "/ld";
#         </script>
#
#
#     <div class="js-log-jamData hidden"
#          data-make=""
#          data-model=""
#          data-year="2023"
#          data-fuel=""
#          data-type=""
#          data-style=""
#          data-sitename="jdpower.com"
#
#          data-subprod=""
#          data-adunit="/ld"
#          data-prod="landingpage"
#          data-pubtemplate="754c9353-fae2-4b4c-b206-ecff13c58b1a-309"
#          data-Browserlanguage =""
#          data-clc=""
#          data-multikv=""
#          data-section="boat"
#          data-modge=""
#           >
#     </div>
#     <script>
#         $(document).ready(function () {
#             var jamDataSite = '';
#             var jamDataPaidRef = '';
#
#             var $jamDataLog = $('.js-log-jamData');
#             if ($jamDataLog.length) {
#                 if (typeof dartSiteName !== 'undefined') {
#                     jamDataSite = dartSiteName;
#                 }
#                 if (typeof paidref !== 'undefined'
#                     && paidref) {
#                     jamDataPaidRef = paidref;
#                 }
#
#                 $jamDataLog.attr('data-site', jamDataSite);
#                 $jamDataLog.attr('data-paidref', jamDataPaidRef);
#             }
#         });
#     </script>
#
#
#
#
#     <script type="text/javascript" src="https://dt-prod-shoppingtools-inline.azurewebsites.net/app/shoppingtools/Scripts/widget-inline.js?gid=0000-2345"></script>
#
#     <script type="text/javascript">!function () { var b = function () { window.__AudioEyeSiteHash = "1cbae281b06029ba68ce6a195a54821b"; var a = document.createElement("script"); a.src = "https://wsmcdn.audioeye.com/aem.js"; a.type = "text/javascript"; a.setAttribute("async", ""); document.getElementsByTagName("body")[0].appendChild(a) }; "complete" !== document.readyState ? window.addEventListener ? window.addEventListener("load", b) : window.attachEvent && window.attachEvent("onload", b) : b() }();</script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'792d5ca49bada22f',m:'aTqJeYUR.uDsYGxQ6bUp.xGN_CzQC1AO1P6C.qPQZ8I-1675282555-0-AYU6kFC6Bs84bGb6MiMN9N8X1JAyhmrSUO6WaNKUKy7IQ5BQ34EV52ecMyUfCl0Q0BSQbI+Qjv905ff60kJeTN/rojhUrAZpRVm7XRd4NC4HFJlwfGJbNgyAyya2bThuXg==',s:[0x38631e0b78,0x568e6a5f05],u:'/cdn-cgi/challenge-platform/h/b'};var now=Date.now()/1000,offset=14400,ts=''+(Math.floor(now)-Math.floor(now%offset)),_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/h/b/scripts/alpha/invisible.js?ts='+ts,document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script><script defer src="https://static.cloudflareinsights.com/beacon.min.js/vaafb692b2aea4879b33c060e79fe94621666317369993" integrity="sha512-0ahDYl866UMhKuYcW078ScMalXqtFJggm7TmlUtp0UlD4eQk0Ixfnm5ykXKvGJNFjLMoortdseTfsRT8oCfgGA==" data-cf-beacon='{"rayId":"792d5ca49bada22f","token":"b7887218795d48a4accb5c2661aff4f7","version":"2022.11.3","si":100}' crossorigin="anonymous"></script>
# </body>
# </html>

# %%
# setting up the soup (parsing through the html on the URL)
soup = BeautifulSoup(page.content, "html.parser")

# %%
# finding all elements that have the specified class in the soup
results = soup.find_all(__class="something")
